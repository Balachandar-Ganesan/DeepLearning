# %%
import string

def count_letters(name):
  """
  Counts the frequency of each letter in a name and returns a list of 26 integers.

  Args:
    name: The input name as a string.

  Returns:
    A list of 26 integers, where the value at each index corresponds to
    the count of the letter at that index in the lowercase English alphabet.
  """

  # 1. Initialize a list of 26 zeros, one for each letter of the alphabet.
  counts = [0] * 26  #

  # 2. Convert the input name to lowercase to ensure case-insensitivity.
  lower_name = name.lower()

  # 3. Iterate through each character in the alphabet.
  for i, letter in enumerate(string.ascii_lowercase): #
    # 4. Count the occurrences of the current letter in the name.
    letter_count = lower_name.count(letter)  #

    # 5. Assign the count to the corresponding index in the results list.
    counts[i] = letter_count

  return counts

# Example usage:
my_name = "Mamata Banerjee"
letter_counts = count_letters(my_name)

print(f"Name: {my_name}")
print(f"Letter counts: {letter_counts}")

# Optional: To see which letter corresponds to each count
for i, count in enumerate(letter_counts):
  letter = string.ascii_lowercase[i]
  if count > 0:
    print(f"'{letter}': {count}")
# Out:
# Name: Mamata Banerjee
# Letter counts: [4, 1, 0, 0, 3, 0, 0, 0, 0, 1, 0, 0, 2, 1, 0, 0, 0, 1, 0, 1, 0, 0, 0, 0, 0, 0]
# 'a': 4
# 'b': 1
# 'e': 3
# 'j': 1
# 'm': 2
# 'n': 1
# 'r': 1
# 't': 1

# %%
def nameEmbedding(name,intGender):
  letter_counts = count_letters(name)
  letter_counts.append(intGender)
  #print(letter_counts
  return (letter_counts)

# %%
# !pip install Faker
# Out:
# Collecting Faker
#   Downloading faker-40.4.0-py3-none-any.whl.metadata (16 kB)
# Downloading faker-40.4.0-py3-none-any.whl (2.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 22.1 MB/s eta 0:00:00
# Installing collected packages: Faker
# Successfully installed Faker-40.4.0

# %%
from faker import Faker
import pandas as pd

    # Initialize Faker with the Indian English locale (en_IN)
fake = Faker('en_IN')



lstnameEmbedding=[]

    # Generate multiple Indian male names

for _ in range(500):
        lstnameEmbedding.append(nameEmbedding(fake.name_male(),0.9))




    # Generate multiple Indian female names

for _ in range(500):
        lstnameEmbedding.append(nameEmbedding(fake.name_female(),0.1))
df = pd.DataFrame(lstnameEmbedding)
df.to_csv('nameEmbedding.csv', index=False)

# %%
import numpy as np
import torch
import torch.nn as nn
import torch.optim as optim

# load the dataset, split into input (X) and output (y) variables
dataset = np.genfromtxt('/content/nameEmbedding.csv', delimiter=',',skip_header=1)
X = dataset[:,0:26]
y = dataset[:,26]

X = torch.tensor(X, dtype=torch.float32)
y = torch.tensor(y, dtype=torch.float32).reshape(-1, 1)

# define the model
model = nn.Sequential(
    nn.Linear(26, 12),
    nn.ReLU(),
    nn.Linear(12, 8),
    nn.ReLU(),
    nn.Linear(8, 1),
    nn.Sigmoid()
)
print(model)

# train the model
loss_fn   = nn.BCELoss()  # binary cross entropy
optimizer = optim.Adam(model.parameters(), lr=0.001)

n_epochs = 100
batch_size = 10

for epoch in range(n_epochs):
    for i in range(0, len(X), batch_size):
        Xbatch = X[i:i+batch_size]
        y_pred = model(Xbatch)
        ybatch = y[i:i+batch_size]
        loss = loss_fn(y_pred, ybatch)
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
    print(f'Finished epoch {epoch}, latest loss {loss}')

# compute accuracy (no_grad is optional)
# Out:
# Sequential(
#   (0): Linear(in_features=26, out_features=12, bias=True)
#   (1): ReLU()
#   (2): Linear(in_features=12, out_features=8, bias=True)
#   (3): ReLU()
#   (4): Linear(in_features=8, out_features=1, bias=True)
#   (5): Sigmoid()
# )
# Finished epoch 0, latest loss 0.7570614218711853
# Finished epoch 1, latest loss 0.7192482948303223
# Finished epoch 2, latest loss 0.7055677175521851
# Finished epoch 3, latest loss 0.7018837332725525
# Finished epoch 4, latest loss 0.7006838321685791
# Finished epoch 5, latest loss 0.6996433138847351
# Finished epoch 6, latest loss 0.6985360980033875
# Finished epoch 7, latest loss 0.6974837183952332
# Finished epoch 8, latest loss 0.6965266466140747
# Finished epoch 9, latest loss 0.6953956484794617
# Finished epoch 10, latest loss 0.6937471628189087
# Finished epoch 11, latest loss 0.6926218867301941
# Finished epoch 12, latest loss 0.6906675100326538
# Finished epoch 13, latest loss 0.6879895925521851
# Finished epoch 14, latest loss 0.6850011944770813
# Finished epoch 15, latest loss 0.6819096803665161
# Finished epoch 16, latest loss 0.6778419017791748
# Finished epoch 17, latest loss 0.6722213625907898
# Finished epoch 18, latest loss 0.6658773422241211
# Finished epoch 19, latest loss 0.6587516069412231
# Finished epoch 20, latest loss 0.651544451713562
# Finished epoch 21, latest loss 0.6478064656257629
# Finished epoch 22, latest loss 0.6433916687965393
# Finished epoch 23, latest loss 0.6382109522819519
# Finished epoch 24, latest loss 0.6346096396446228
# Finished epoch 25, latest loss 0.6326749920845032
# Finished epoch 26, latest loss 0.6294137239456177
# Finished epoch 27, latest loss 0.627234160900116
# Finished epoch 28, latest loss 0.6279124617576599
# Finished epoch 29, latest loss 0.6245192289352417
# Finished epoch 30, latest loss 0.6231041550636292
# Finished epoch 31, latest loss 0.6220951676368713
# Finished epoch 32, latest loss 0.6197773814201355
# Finished epoch 33, latest loss 0.619126558303833
# Finished epoch 34, latest loss 0.6192092895507812
# Finished epoch 35, latest loss 0.6194452047348022
# Finished epoch 36, latest loss 0.6208195686340332
# Finished epoch 37, latest loss 0.6208736896514893
# Finished epoch 38, latest loss 0.619928777217865
# Finished epoch 39, latest loss 0.6187494993209839
# Finished epoch 40, latest loss 0.6177975535392761
# Finished epoch 41, latest loss 0.6190738677978516
# Finished epoch 42, latest loss 0.6188260912895203
# Finished epoch 43, latest loss 0.6203051805496216
# Finished epoch 44, latest loss 0.6198437213897705
# Finished epoch 45, latest loss 0.6201281547546387
# Finished epoch 46, latest loss 0.6208553910255432
# Finished epoch 47, latest loss 0.621802806854248
# Finished epoch 48, latest loss 0.6223646402359009
# Finished epoch 49, latest loss 0.6226308345794678
# Finished epoch 50, latest loss 0.6220864653587341
# Finished epoch 51, latest loss 0.6219771504402161
# Finished epoch 52, latest loss 0.6214793920516968
# Finished epoch 53, latest loss 0.6204572319984436
# Finished epoch 54, latest loss 0.6199339032173157
# Finished epoch 55, latest loss 0.6187170147895813
# Finished epoch 56, latest loss 0.6179165840148926
# Finished epoch 57, latest loss 0.6171280741691589
# Finished epoch 58, latest loss 0.6173755526542664
# Finished epoch 59, latest loss 0.6148840188980103
# Finished epoch 60, latest loss 0.6157007217407227
# Finished epoch 61, latest loss 0.6157263517379761
# Finished epoch 62, latest loss 0.6163219809532166
# Finished epoch 63, latest loss 0.6168232560157776
# Finished epoch 64, latest loss 0.6165205240249634
# Finished epoch 65, latest loss 0.6159645318984985
# Finished epoch 66, latest loss 0.6155871152877808
# Finished epoch 67, latest loss 0.6132897138595581
# Finished epoch 68, latest loss 0.6138712763786316
# Finished epoch 69, latest loss 0.6124640107154846
# Finished epoch 70, latest loss 0.611477255821228
# Finished epoch 71, latest loss 0.6104660034179688
# Finished epoch 72, latest loss 0.6111180186271667
# Finished epoch 73, latest loss 0.6101099848747253
# Finished epoch 74, latest loss 0.6102498769760132
# Finished epoch 75, latest loss 0.6109598875045776
# Finished epoch 76, latest loss 0.6106694936752319
# Finished epoch 77, latest loss 0.6097721457481384
# Finished epoch 78, latest loss 0.6102535128593445
# Finished epoch 79, latest loss 0.6119027137756348
# Finished epoch 80, latest loss 0.6124188303947449
# Finished epoch 81, latest loss 0.6114603877067566
# Finished epoch 82, latest loss 0.6107080578804016
# Finished epoch 83, latest loss 0.6120784282684326
# Finished epoch 84, latest loss 0.6115471720695496
# Finished epoch 85, latest loss 0.608993411064148
# Finished epoch 86, latest loss 0.6091108322143555
# Finished epoch 87, latest loss 0.6080151200294495
# Finished epoch 88, latest loss 0.6078500747680664
# Finished epoch 89, latest loss 0.6065314412117004
# Finished epoch 90, latest loss 0.6057724356651306
# Finished epoch 91, latest loss 0.6050103306770325
# Finished epoch 92, latest loss 0.6034088134765625
# Finished epoch 93, latest loss 0.6017058491706848
# Finished epoch 94, latest loss 0.6008053421974182
# Finished epoch 95, latest loss 0.6002707481384277
# Finished epoch 96, latest loss 0.5990012884140015
# Finished epoch 97, latest loss 0.5995312929153442
# Finished epoch 98, latest loss 0.5997730493545532
# Finished epoch 99, latest loss 0.5971879959106445

# %%
def predictGenderFromName(strName):
  y_pred=model(torch.tensor(count_letters(strName),dtype=torch.float32))

  if y_pred >0.5:
      print('Male')
  else:
      print('Female')

# %%
predictGenderFromName('Anand')
predictGenderFromName('Vidhya')
predictGenderFromName('Anandhi')
predictGenderFromName('Ramesh')
predictGenderFromName('Shankar')
predictGenderFromName('Shankari')
# Out:
# Male
# Female
# Female
# Male
# Male
# Female

# %%
#wrong predictions increase epoch to 1000 train the model again and verify
print('if Wrong , Increase epoch to 1000 and see results')
predictGenderFromName('Shaji')
predictGenderFromName('Kiran')
# Out:
# if Wrong , Increase epoch to 1000 and see results
# Female
# Female
