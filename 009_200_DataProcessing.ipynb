# %% [markdown]
# <a href="https://colab.research.google.com/github/Balachandar-Ganesan/DeepLearning/blob/main/009_200_DataProcessing.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
# !wget https://raw.githubusercontent.com/Balachandar-Ganesan/DeepLearning/refs/heads/main/Bias_correction_ucl.csv

# %%
df = pd.read_csv('/content/Bias_correction_ucl.csv')
df

# %%
df.drop('Date', inplace=True, axis=1)

# %%
ax = df['Present_Tmax'].hist(color='gray')
ax.set_xlabel("Temperature")
ax.set_ylabel("Frequency")
# Out:
# Text(0, 0.5, 'Frequency')

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()
df2 = scaler.fit_transform(df)
df2 = pd.DataFrame(df2, columns=df.columns)

# %%
ax = df2['Present_Tmax'].hist(color='gray')
ax.set_xlabel("Normalized Temperature")
ax.set_ylabel("Frequency")
# Out:
# --2026-03-03 06:35:35--  https://github.com/PacktWorkshops/The-TensorFlow-Workshop/tree/master/Chapter02/Datasets/image_data
# Resolving github.com (github.com)... 140.82.113.3
# Connecting to github.com (github.com)|140.82.113.3|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘image_data’
#
# image_data              [ <=>                ] 187.56K  --.-KB/s    in 0.05s
#
# 2026-03-03 06:35:35 (3.73 MB/s) - ‘image_data’ saved [192057]
